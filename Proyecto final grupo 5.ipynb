# %%
# Importamos pandas
import pandas as pd

# %%
# aplicamos la configuración que nos permite ver todas las columnas
pd.set_option('display.max_columns', None)

# %%
# Leemos el csv de la encuesta y vemos cuántas filas y columnas tiene
df_answers = pd.read_csv("multiple_choice_responses.csv")
print(df_answers.head())
print(f"Tenemos {df_answers.shape[0]} filas y {df_answers.shape[1]} columnas")
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# ...

# %%
# Después de ver las columnas que necesitaremos para hacer las gráficas, eliminamos aquellas que no utilizaremos, y las que no tienen 
# información relevante
columnas_a_eliminar  = ["Time from Start to Finish (seconds)", "Q2_OTHER_TEXT", "Q5_OTHER_TEXT", "Q7", "Q8", "Q9_Part_1", "Q9_Part_2", 
                        "Q9_Part_3",	"Q9_Part_4",	"Q9_Part_5", "Q9_Part_6", "Q9_Part_7", "Q9_Part_8", "Q9_OTHER_TEXT", "Q11", 
                        "Q12_OTHER_TEXT", "Q13_OTHER_TEXT", "Q14_Part_1_TEXT","Q14_Part_2_TEXT", "Q14_Part_3_TEXT",	"Q14_Part_4_TEXT", 
                        "Q14_Part_5_TEXT",	"Q14_OTHER_TEXT", "Q16_OTHER_TEXT", "Q17_OTHER_TEXT", "Q18_OTHER_TEXT", "Q19_OTHER_TEXT", 
                        "Q20_OTHER_TEXT", "Q21_Part_1",	"Q21_Part_2",	"Q21_Part_3",	"Q21_Part_4",	"Q21_Part_5", "Q21_OTHER_TEXT", 
                        "Q22", "Q23", "Q24_Part_1",	"Q24_Part_2",	"Q24_Part_3",	"Q24_Part_4",	"Q24_Part_5",	"Q24_Part_6",	
                        "Q24_Part_7",	"Q24_Part_8",	"Q24_Part_9",	"Q24_Part_10",	"Q24_Part_11",	"Q24_Part_12",	"Q24_OTHER_TEXT", 
                        "Q25_Part_1",	"Q25_Part_2",	"Q25_Part_3", "Q25_Part_4",	"Q25_Part_5",	"Q25_Part_6",	"Q25_Part_7",	
                        "Q25_Part_8",	"Q25_OTHER_TEXT", "Q26_Part_1",	"Q26_Part_2",	"Q26_Part_3",	"Q26_Part_4",	"Q26_Part_5",	
                        "Q26_Part_6",	"Q26_Part_7",	"Q26_OTHER_TEXT",	"Q27_Part_1",	"Q27_Part_2",	"Q27_Part_3",	"Q27_Part_4",	
                        "Q27_Part_5",	"Q27_Part_6",	"Q27_OTHER_TEXT",	"Q28_Part_1",	"Q28_Part_2",	"Q28_Part_3",	"Q28_Part_4",	
                        "Q28_Part_5",	"Q28_Part_6",	"Q28_Part_7",	"Q28_Part_8",	"Q28_Part_9",	"Q28_Part_10","Q28_Part_11",	
                        "Q28_Part_12",	"Q28_OTHER_TEXT", "Q29_Part_1",	"Q29_Part_2",	"Q29_Part_3",	"Q29_Part_4",	"Q29_Part_5",	
                        "Q29_Part_6",	"Q29_Part_7",	"Q29_Part_8",	"Q29_Part_9",	"Q29_Part_10",	"Q29_Part_11",	"Q29_Part_12",	
                        "Q29_OTHER_TEXT", "Q30_Part_1",	"Q30_Part_2",	"Q30_Part_3",	"Q30_Part_4",	"Q30_Part_5",	"Q30_Part_6",	
                        "Q30_Part_7",	"Q30_Part_8",	"Q30_Part_9",	"Q30_Part_10",	"Q30_Part_11",	"Q30_Part_12",	"Q30_OTHER_TEXT", 
                        "Q31_Part_1",	"Q31_Part_2",	"Q31_Part_3",	"Q31_Part_4",	"Q31_Part_5",	"Q31_Part_6",	"Q31_Part_7",	
                        "Q31_Part_8",	"Q31_Part_9",	"Q31_Part_10",	"Q31_Part_11",	"Q31_Part_12",	"Q31_OTHER_TEXT",	"Q32_Part_1",	
                        "Q32_Part_2",	"Q32_Part_3",	"Q32_Part_4",	"Q32_Part_5",	"Q32_Part_6",	"Q32_Part_7",	"Q32_Part_8",	
                        "Q32_Part_9",	"Q32_Part_10",	"Q32_Part_11",	"Q32_Part_12",	"Q32_OTHER_TEXT",	"Q33_Part_1",	"Q33_Part_2",	
                        "Q33_Part_3",	"Q33_Part_4",	"Q33_Part_5",	"Q33_Part_6",	"Q33_Part_7",	"Q33_Part_8",	"Q33_Part_9",	
                        "Q33_Part_10",	"Q33_Part_11",	"Q33_Part_12",	"Q33_OTHER_TEXT", "Q34_OTHER_TEXT"]
df_answers = df_answers.drop(columns=columnas_a_eliminar)
print(df_answers.head())
# Out:
#                             Q1                                      Q2  \
# 0  What is your age (# years)?  What is your gender? - Selected Choice
# 1                        22-24                                    Male
# 2                        40-44                                    Male
# 3                        55-59                                  Female
# 4                        40-44                                    Male
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
# 3                                    Germany
# 4                                  Australia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
# ...

# %%
# Confirmamos si eliminamos las columnas correctas
df_answers.columns
# Out:
# Index(['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q10', 'Q12_Part_1', 'Q12_Part_2',
#        'Q12_Part_3', 'Q12_Part_4', 'Q12_Part_5', 'Q12_Part_6', 'Q12_Part_7',
#        'Q12_Part_8', 'Q12_Part_9', 'Q12_Part_10', 'Q12_Part_11', 'Q12_Part_12',
#        'Q13_Part_1', 'Q13_Part_2', 'Q13_Part_3', 'Q13_Part_4', 'Q13_Part_5',
#        'Q13_Part_6', 'Q13_Part_7', 'Q13_Part_8', 'Q13_Part_9', 'Q13_Part_10',
#        'Q13_Part_11', 'Q13_Part_12', 'Q14', 'Q15', 'Q16_Part_1', 'Q16_Part_2',
#        'Q16_Part_3', 'Q16_Part_4', 'Q16_Part_5', 'Q16_Part_6', 'Q16_Part_7',
#        'Q16_Part_8', 'Q16_Part_9', 'Q16_Part_10', 'Q16_Part_11', 'Q16_Part_12',
#        'Q17_Part_1', 'Q17_Part_2', 'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5',
#        'Q17_Part_6', 'Q17_Part_7', 'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10',
#        'Q17_Part_11', 'Q17_Part_12', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_Part_7', 'Q18_Part_8',
# ...

# %%
# Renombramos a las columnas para que tengan nombres más significativos, acordes a la pregunta a la que corresponden de la encuesta

df_answers.rename(columns = {'Q1':"Age", 'Q2':"Gender", 'Q3':"Country", 'Q4':"Education level", 'Q5':"Job role", 'Q6':"Company size", 
                                'Q10':"Salary ($)", 'Q12_Part_1':"MS1: Twitter", 'Q12_Part_2':"MS2: Hacker News",'Q12_Part_3':"MS3: Reddit",
                                'Q12_Part_4':"MS4: Kaggle", 'Q12_Part_5':"MS5: Course Forums", 'Q12_Part_6':"MS6: Youtube", 
                                'Q12_Part_7':"MS7: Podcasts",'Q12_Part_8':"MS8: Blogs", 'Q12_Part_9':"MS9: Journal Publications", 
                                'Q12_Part_10':"MS10: Slack Communities", 'Q12_Part_11':"MS11: None", 'Q12_Part_12':"MS12: Other",
                                'Q13_Part_1':"Platform 1: Udacity", 'Q13_Part_2':"Platform 2: Coursera", 'Q13_Part_3':"Platform 3: EdX",
                                'Q13_Part_4':"Platform 4: Datacamp", 'Q13_Part_5':"Platform 5: Dataquest", 'Q13_Part_6':"Platform 6: Kaggle Courses",
                                'Q13_Part_7':"Platform 7: Fast.AI", 'Q13_Part_8':"Platform 8: Udemy", 'Q13_Part_9':"Platform 9: LinkedIn Learning",
                                'Q13_Part_10':"Platform 10: University Courses", 'Q13_Part_11':"Platform 11: None", 'Q13_Part_12':"Platform 12: Other",
                                'Q14':"Primary Tool", 'Q15':"Time writing code", 'Q16_Part_1':"Environment 1: Jupyter", 'Q16_Part_2':"Environment 2: RStudio",
                                'Q16_Part_3':"Environment 3: PyCharm", 'Q16_Part_4':"Environment 4: Atom", 'Q16_Part_5':"Environment 5: MATLAB",
                                'Q16_Part_6':"Environment 6: Visual Studio Code", 'Q16_Part_7':"Environment 7: Spyder", 'Q16_Part_8':"Environment 8: Vim/Emacs",
                                'Q16_Part_9':"Environment 9: Notepad ++", 'Q16_Part_10':"Environment 10: Sublime Text", 'Q16_Part_11':"Environment 11: None",
                                'Q16_Part_12':"Environment 12: Other", 'Q17_Part_1':"Notebooks 1: Kaggle Notebooks Kernels", 'Q17_Part_2':"Notebooks 2: Google Colab",
                                'Q17_Part_3':"Notebooks 3: Microsoft Azure Notebooks", 'Q17_Part_4':"Notebooks 4: Google Cloud Notebook", 
                                'Q17_Part_5':"Notebooks 5: Paperspace/Gradient", 'Q17_Part_6':"Notebooks 6: FloydHub", 'Q17_Part_7':"Notebooks 7: Binder/JupyterHub",
                                'Q17_Part_8':"Notebooks 8: IMB Watson Studio", 'Q17_Part_9':"Notebooks 9: Code Ocean", 'Q17_Part_10':"Notebooks 10: AWS Notebook Products",
                                'Q17_Part_11':"Notebooks 11: None", 'Q17_Part_12':"Notebooks 12: Others",  'Q18_Part_1': "Languages 1: Python", 
                                'Q18_Part_2': "Languages 2: R", 'Q18_Part_3': "Languages 3: SQL",'Q18_Part_4': "Languages 4: C", 'Q18_Part_5': "Languages 5: C++", 
                                'Q18_Part_6': "Languages 6: Java", 'Q18_Part_7': "Languages 7: JavaScript", 'Q18_Part_8': "Languages 8; TypeScript",
                                'Q18_Part_9': "Languages 9: Bash", 'Q18_Part_10': "Languages 10: MatLab", 'Q18_Part_11': "Languages 11: None", 
                                'Q18_Part_12': "Languages 12: Other", 'Q19': "Recommended language",'Q20_Part_1': "Libraries 1: Ggplot/ggplot2", 
                                'Q20_Part_2': "Libraries 2: Matplotlib", 'Q20_Part_3': "Libraries 3: Altair", 'Q20_Part_4': "Libraries 4: Shiny", 
                                'Q20_Part_5': "Libraries 5: D3.js", 'Q20_Part_6': "Libraries 6: Plotly/Plotly Express", 'Q20_Part_7': "Libraries 7: Bokeh", 
                                'Q20_Part_8': "Libraries 8: Seaborn", 'Q20_Part_9': "Libraries 9: Geoplotlib", 'Q20_Part_10': "Libraries 10: Leaflet/Folium",
                                'Q20_Part_11': "Libraries 11: None", 'Q20_Part_12': "Libraries 12: Other", 'Q34_Part_1': "R Database 1: MySQL", 
                                'Q34_Part_2': "R Database 2: PostgresSQL", 'Q34_Part_3': "R Database 3: SQLite",'Q34_Part_4': "R Database 4: Miscrosoft SQL Server", 
                                'Q34_Part_5': "R Database 5: Oracle Database", 'Q34_Part_6': "R Database 6: Microsoft Access", 'Q34_Part_7': "R Database 7: AWS DynamoDB", 
                                'Q34_Part_8': "R Database 8: AWS DynamoDB",'Q34_Part_9': "R Database 9: Azure SQL Database", 'Q34_Part_10': "R Database 10: Google Cloud SQL", 
                                'Q34_Part_11': "R Database 11: None", 'Q34_Part_12': "R Database 12: Other"}, inplace=True)

# %%
# Vemos si hemos cambiado los nombres correctamente

df_answers.head(3)
# Out:
#                            Age                                  Gender  \
# 0  What is your age (# years)?  What is your gender? - Selected Choice
# 1                        22-24                                    Male
# 2                        40-44                                    Male
#
#                                      Country  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
#
#                                      Education level  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
#
#                                             Job role  \
# 0  Select the title most similar to your current ...
# 1                                  Software Engineer
# 2                                  Software Engineer
#
#                                         Company size  \
# ...

# %%
# Eliminamos la fila que contiene las preguntas de la encuesta
df_answers.drop(0, inplace=True)

# %%
df_answers.head(3)
# Out:
#      Age  Gender  Country      Education level           Job role  \
# 1  22-24    Male   France      Master’s degree  Software Engineer
# 2  40-44    Male    India  Professional degree  Software Engineer
# 3  55-59  Female  Germany  Professional degree                NaN
#
#            Company size     Salary ($)                        MS1: Twitter  \
# 1  1000-9,999 employees  30,000-39,999  Twitter (data science influencers)
# 2    > 10,000 employees    5,000-7,499                                 NaN
# 3                   NaN            NaN                                 NaN
#
#   MS2: Hacker News MS3: Reddit                               MS4: Kaggle  \
# 1              NaN         NaN  Kaggle (forums, blog, social media, etc)
# 2              NaN         NaN  Kaggle (forums, blog, social media, etc)
# 3              NaN         NaN                                       NaN
#
#   MS5: Course Forums                                     MS6: Youtube  \
# ...

# %%
df_answers.to_csv("df_answers.csv", index=True)
